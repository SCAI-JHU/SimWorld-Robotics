# %%
from multi_agent_task_generator import MultiAgentTaskGenerator
import os
# Out:
# Using custom box path: d:\github\simworld\clpg\clpg\..\data\Bbox.json

# %%
task_generator = MultiAgentTaskGenerator(load_map=False)
# Out:
# INFO:__init__:230:Got connection confirm: b'connected to gym_citynav'
# =>Info: using ip-port socket

# %%
map_names = ['map_roud_20_7', 'map_roud_20_8', 'map_roud_20_9']
for map_name in map_names:
    city_path = os.path.join(os.getcwd(), 'input_map', 'single_world', 'total', map_name, 'progen_world.json')
    road_path = os.path.join(os.getcwd(), 'input_map', 'single_world', 'total', map_name, 'roads.json')
    task_generator.load_env(city_path, road_path, False)
    save_path = os.path.join(os.getcwd(), 'output', 'multi_agent_task', map_name)
    task_generator.generate_images(save_path)
# Out:
# Importing city data from d:\github\SimWorld\task_generator\input_map\single_world\total\map_roud_20_7\progen_world.json
# Import completed successfully
# Imported road segments: 20
# Imported buildings: 145
# Imported details: 0
# Error reading image: a bytes-like object is required, not 'str'
# Error reading image: a bytes-like object is required, not 'str'
# Error reading image: a bytes-like object is required, not 'str'
# Error reading image: a bytes-like object is required, not 'str'
# Error reading image: a bytes-like object is required, not 'str'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 task_generator.load_env(city_path, road_path, False)
#       6 save_path = os.path.join(os.getcwd(), 'output', 'multi_agent_task', map_name)
# ----> 7 task_generator.generate_images(save_path)
#       8 break
#
# ...

# %%
task_generator.total_buildings[0]['building'].building_type.name
# Out:
# 'BP_Building_05_C'

# %%
import json
import os
import random

# %%
map_name = 'map_roud_20_0'
input_map_folder = os.path.join(os.getcwd(), 'input_map', 'single_world', 'total', map_name)
city_path = os.path.join(input_map_folder, 'progen_world.json')
road_path = os.path.join(input_map_folder, 'roads.json')
save_path = os.path.join(os.getcwd(), 'output', 'multi_agent_task', 'tasks')
map_folder = os.path.join(os.getcwd(), 'output', 'multi_agent_task', 'maps', map_name)
task_generator.generate_task(map_folder, city_path, road_path, 'easy', save_path, 0, 1000)
# Out:
# Importing city data from d:\github\SimWorld\task_generator\input_map\single_world\total\map_roud_20_0\progen_world.json
# Import completed successfully
# Imported road segments: 20
# Imported buildings: 154
# Imported details: 0
